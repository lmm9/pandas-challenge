# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load, encoding="utf-8")
student_data = pd.read_csv(student_data_to_load, encoding="utf-8")

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
#Calculate the total number of schools
total_schools=len(school_data_complete["school_name"].value_counts())
total_schools
# Out:
# 15

# %%
#Calculate the total number of students
total_students=len(school_data_complete["Student ID"].value_counts())
total_students
# Out:
# 39170

# %%
#Calculate the total budget
total_budget=school_data["budget"].sum()
total_budget
# Out:
# 24649428

# %%
#Calculate the average math score
avg_math=school_data_complete["math_score"].sum()/len(school_data_complete["Student ID"].value_counts())
avg_math
# Out:
# 78.98537145774827

# %%
#Calculate the average reading score
avg_read=school_data_complete["reading_score"].sum()/len(school_data_complete["Student ID"].value_counts())
avg_read
# Out:
# 81.87784018381414

# %%
#Calculate the percentage of students with a passing math score (70 or greater)
school_data_complete["math_pass"]=(school_data_complete["math_score"] >=70)
math_perc=100*len(school_data_complete.loc[school_data_complete["math_pass"]==True])/total_students

#Calculate the percentage of students with a passing reading score (70 or greater)
school_data_complete["read_pass"]=(school_data_complete["reading_score"] >=70)
read_perc=100*len(school_data_complete.loc[school_data_complete["read_pass"]==True])/total_students

#Calculate the percentage of students who passed math and reading (% Overall Passing)
school_data_complete["overall_pass"]=(school_data_complete["reading_score"] >=70)&(school_data_complete["math_score"] >=70)
overall_perc=100*len(school_data_complete.loc[school_data_complete["overall_pass"]==True])/total_students

#Display new complete Dataframe
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget  math_pass  \
# 0             66          79          0  District  2917  1910635       True
# 1             94          61          0  District  2917  1910635      False
# 2             90          60          0  District  2917  1910635      False
# 3             67          58          0  District  2917  1910635      False
# 4             97          84          0  District  2917  1910635       True
#
#    read_pass  overall_pass
# 0      False         False
# 1       True         False
# 2       True         False
# ...

# %%
#Create a dataframe to hold the above results
district_summary_df = pd.DataFrame([{"Total Schools":total_schools,
                                   "Total Students":total_students,
                                   "Total Budget":total_budget,
                                   "Average Math Score":avg_math,
                                   "Average Reading Score":avg_read,
                                   "% Passing Math": math_perc,
                                   "% Passing Reading": read_perc,
                                   "% Overall Passing": overall_perc}
                                  ])
                            
district_summary_df.head()
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %%
#Give the displayed data cleaner formatting
district_summary_df["Total Schools"] = district_summary_df["Total Schools"].map("{:,}".format)
district_summary_df["Total Students"] = district_summary_df["Total Students"].map("{:,}".format)
district_summary_df["Total Budget"] = district_summary_df["Total Budget"].map("${:,}".format)
district_summary_df["Average Math Score"] = district_summary_df["Average Math Score"].map("{:.2f}".format)
district_summary_df["Average Reading Score"] = district_summary_df["Average Reading Score"].map("{:.2f}".format)
district_summary_df["% Passing Math"] = district_summary_df["% Passing Math"].map("{:.2f}".format)
district_summary_df["% Passing Reading"] = district_summary_df["% Passing Reading"].map("{:.2f}".format)
district_summary_df["% Overall Passing"] = district_summary_df["% Overall Passing"].map("{:.2f}".format)
district_summary_df.head()
# Out:
#   Total Schools Total Students Total Budget Average Math Score  \
# 0            15         39,170  $24,649,428              78.99
#
#   Average Reading Score % Passing Math % Passing Reading % Overall Passing
# 0                 81.88          74.98             85.81             65.17

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %% [markdown]
# ## School Summary

# %%
#Pull Up School Name, School Type,Total Students, Total School Budget
school_data.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
#Create sum of math and reading score and pass percentages
schoolgroup_df=school_data_complete.groupby(["school_name"])
schoolgroup_df.sum()
school_df=schoolgroup_df.sum()
school_df.head()
# Out:
#                       Student ID  reading_score  math_score  School ID  \
# school_name
# Bailey High School     101303896         403225      383393      34832
# Cabrera High School     31477307         156027      154329      11148
# Figueroa High School    12949059         239335      226223       2949
# Ford High School        99055935         221164      211184      35607
# Griffin High School     19077394         123043      122360       5872
#
#                           size       budget  math_pass  read_pass  \
# school_name
# Bailey High School    24760576  15549641728     3318.0     4077.0
# Cabrera High School    3452164   2009159448     1749.0     1803.0
# Figueroa High School   8696601   5557128039     1946.0     2381.0
# Ford High School       7502121   4831365924     1871.0     2172.0
# Griffin High School    2155024   1346890000     1371.0     1426.0
#
#                       overall_pass
# school_name
# Bailey High School          2719.0
# ...

# %%
#Merge two dataframes with school info
school_merge = pd.merge(school_data, school_df, on=["school_name"])
school_merge.head()
# Out:
#    School ID_x            school_name      type  size_x  budget_x  Student ID  \
# 0            0      Huang High School  District    2917   1910635     4252986
# 1            1   Figueroa High School  District    2949   1884411    12949059
# 2            2    Shelton High School   Charter    1761   1056600    11879706
# 3            3  Hernandez High School  District    4635   3022020    46090440
# 4            4    Griffin High School   Charter    1468    917500    19077394
#
#    reading_score  math_score  School ID_y    size_y     budget_y  math_pass  \
# 0         236810      223528            0   8508889   5573322295     1916.0
# 1         239335      226223         2949   8696601   5557128039     1946.0
# 2         147441      146796         3522   3101121   1860672600     1653.0
# 3         375131      358238        13905  21483225  14007062700     3094.0
# 4         123043      122360         5872   2155024   1346890000     1371.0
#
#    read_pass  overall_pass
# ...

# %%
#rename column headings
school_rename_df = school_merge.rename(columns={"School ID_x": "school_id",
                                        "size_x": "school_students",
                                        "budget_x": "school_budget"})
school_rename_df=school_rename_df.set_index("school_id")
school_rename_df.head()
# Out:
#                      school_name      type  school_students  school_budget  \
# school_id
# 0              Huang High School  District             2917        1910635
# 1           Figueroa High School  District             2949        1884411
# 2            Shelton High School   Charter             1761        1056600
# 3          Hernandez High School  District             4635        3022020
# 4            Griffin High School   Charter             1468         917500
#
#            Student ID  reading_score  math_score  School ID_y    size_y  \
# school_id
# 0             4252986         236810      223528            0   8508889
# 1            12949059         239335      226223         2949   8696601
# 2            11879706         147441      146796         3522   3101121
# 3            46090440         375131      358238        13905  21483225
# 4            19077394         123043      122360         5872   2155024
#
# ...

# %%
#Calculate Per Student Budget, Average Math Score, Average Reading Score, 
#% Passing Math, % Passing Reading, % Overall Passing 
school_rename_df["student_budget"]=school_rename_df["school_budget"]/school_rename_df["school_students"]
school_rename_df["math_avg"]=school_rename_df["math_score"]/school_rename_df["school_students"]
school_rename_df["read_avg"]=school_rename_df["reading_score"]/school_rename_df["school_students"]
school_rename_df["math_passavg"]=100*school_rename_df["math_pass"]/school_rename_df["school_students"]
school_rename_df["read_passavg"]=100*school_rename_df["read_pass"]/school_rename_df["school_students"]
school_rename_df["overall_passavg"]=100*school_rename_df["overall_pass"]/school_rename_df["school_students"]
school_rename_df.head()
# Out:
#                      school_name      type  school_students  school_budget  \
# school_id
# 0              Huang High School  District             2917        1910635
# 1           Figueroa High School  District             2949        1884411
# 2            Shelton High School   Charter             1761        1056600
# 3          Hernandez High School  District             4635        3022020
# 4            Griffin High School   Charter             1468         917500
#
#            Student ID  reading_score  math_score  School ID_y    size_y  \
# school_id
# 0             4252986         236810      223528            0   8508889
# 1            12949059         239335      226223         2949   8696601
# 2            11879706         147441      146796         3522   3101121
# 3            46090440         375131      358238        13905  21483225
# 4            19077394         123043      122360         5872   2155024
#
# ...

# %%
#Select needed columns
school_reduce_df = school_rename_df[["school_name", "type", "school_students",
                       "school_budget", "student_budget","math_avg","read_avg","math_passavg", "read_passavg", "overall_passavg"]]
school_reduce_df.head()
# Out:
#                      school_name      type  school_students  school_budget  \
# school_id
# 0              Huang High School  District             2917        1910635
# 1           Figueroa High School  District             2949        1884411
# 2            Shelton High School   Charter             1761        1056600
# 3          Hernandez High School  District             4635        3022020
# 4            Griffin High School   Charter             1468         917500
#
#            student_budget   math_avg   read_avg  math_passavg  read_passavg  \
# school_id
# 0                   655.0  76.629414  81.182722     65.683922     81.316421
# 1                   639.0  76.711767  81.158020     65.988471     80.739234
# 2                   600.0  83.359455  83.725724     93.867121     95.854628
# 3                   652.0  77.289752  80.934412     66.752967     80.862999
# 4                   625.0  83.351499  83.816757     93.392371     97.138965
#
#            overall_passavg
# ...

# %%
#Select needed columns
school_format_df = school_reduce_df.copy()
school_format_df.head()
# Out:
#                      school_name      type  school_students  school_budget  \
# school_id
# 0              Huang High School  District             2917        1910635
# 1           Figueroa High School  District             2949        1884411
# 2            Shelton High School   Charter             1761        1056600
# 3          Hernandez High School  District             4635        3022020
# 4            Griffin High School   Charter             1468         917500
#
#            student_budget   math_avg   read_avg  math_passavg  read_passavg  \
# school_id
# 0                   655.0  76.629414  81.182722     65.683922     81.316421
# 1                   639.0  76.711767  81.158020     65.988471     80.739234
# 2                   600.0  83.359455  83.725724     93.867121     95.854628
# 3                   652.0  77.289752  80.934412     66.752967     80.862999
# 4                   625.0  83.351499  83.816757     93.392371     97.138965
#
#            overall_passavg
# ...

# %%
#Give the displayed data cleaner formatting
school_format_df["school_students"] = school_format_df["school_students"].map("{:,}".format)
school_format_df["school_budget"] = school_format_df["school_budget"].map("${:,}".format)
school_format_df["student_budget"] = school_format_df["student_budget"].map("${:,}".format)
school_format_df["read_avg"] = school_format_df["read_avg"].map("{:.2f}".format)
school_format_df["math_avg"] = school_format_df["math_avg"].map("{:.2f}".format)
school_format_df["math_passavg"] = school_format_df["math_passavg"].map("{:.2f}".format)
school_format_df["read_passavg"] = school_format_df["read_passavg"].map("{:.2f}".format)
school_format_df["overall_passavg"] = school_format_df["overall_passavg"].map("{:.2f}".format)
school_format_df.head()
# Out:
#                      school_name      type school_students school_budget  \
# school_id
# 0              Huang High School  District           2,917    $1,910,635
# 1           Figueroa High School  District           2,949    $1,884,411
# 2            Shelton High School   Charter           1,761    $1,056,600
# 3          Hernandez High School  District           4,635    $3,022,020
# 4            Griffin High School   Charter           1,468      $917,500
#
#           student_budget math_avg read_avg math_passavg read_passavg  \
# school_id
# 0                 $655.0    76.63    81.18        65.68        81.32
# 1                 $639.0    76.71    81.16        65.99        80.74
# 2                 $600.0    83.36    83.73        93.87        95.85
# 3                 $652.0    77.29    80.93        66.75        80.86
# 4                 $625.0    83.35    83.82        93.39        97.14
#
#           overall_passavg
# school_id
# 0                   53.51
# ...

# %%
#Rename the column headings for cleaner formatting
school_format_df=school_format_df.rename(columns={
    "school_name":"School Name",
    "type":"School Type",
    "school_students":"Total Students",
    "school_budget":"Total School Budget",
    "student_budget":"Per Student Budget",
    "math_avg":"Average Math Score",
    "read_avg":"Average Reading Score",
    "math_passavg":"% Passing Math",
    "read_passavg":"% Passing Reading",
    "overall_passavg":"% Overall Passing"})
school_format_df.head()
# Out:
#                      School Name School Type Total Students  \
# school_id
# 0              Huang High School    District          2,917
# 1           Figueroa High School    District          2,949
# 2            Shelton High School     Charter          1,761
# 3          Hernandez High School    District          4,635
# 4            Griffin High School     Charter          1,468
#
#           Total School Budget Per Student Budget Average Math Score  \
# school_id
# 0                  $1,910,635             $655.0              76.63
# 1                  $1,884,411             $639.0              76.71
# 2                  $1,056,600             $600.0              83.36
# 3                  $3,022,020             $652.0              77.29
# 4                    $917,500             $625.0              83.35
#
#           Average Reading Score % Passing Math % Passing Reading  \
# school_id
# 0                         81.18          65.68             81.32
# ...

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
#Show Highest 5 Overall Pass %
high_perform_df=school_format_df.sort_values("% Overall Passing", ascending=False)
high_perform_df.head(5)
# Out:
#                    School Name School Type Total Students Total School Budget  \
# school_id
# 6          Cabrera High School     Charter          1,858          $1,081,356
# 14          Thomas High School     Charter          1,635          $1,043,130
# 4          Griffin High School     Charter          1,468            $917,500
# 5           Wilson High School     Charter          2,283          $1,319,574
# 9             Pena High School     Charter            962            $585,858
#
#           Per Student Budget Average Math Score Average Reading Score  \
# school_id
# 6                     $582.0              83.06                 83.98
# 14                    $638.0              83.42                 83.85
# 4                     $625.0              83.35                 83.82
# 5                     $578.0              83.27                 83.99
# 9                     $609.0              83.84                 84.04
#
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
##Show Lowest 5 Overall Pass %
low_perform_df=school_format_df.sort_values("% Overall Passing")
low_perform_df.head(5)
# Out:
#                      School Name School Type Total Students  \
# school_id
# 11         Rodriguez High School    District          3,999
# 1           Figueroa High School    District          2,949
# 0              Huang High School    District          2,917
# 3          Hernandez High School    District          4,635
# 12           Johnson High School    District          4,761
#
#           Total School Budget Per Student Budget Average Math Score  \
# school_id
# 11                 $2,547,363             $637.0              76.84
# 1                  $1,884,411             $639.0              76.71
# 0                  $1,910,635             $655.0              76.63
# 3                  $3,022,020             $652.0              77.29
# 12                 $3,094,650             $650.0              77.07
#
#           Average Reading Score % Passing Math % Passing Reading  \
# school_id
# 11                        80.74          66.37             80.22
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget  math_pass  \
# 0             66          79          0  District  2917  1910635       True
# 1             94          61          0  District  2917  1910635      False
# 2             90          60          0  District  2917  1910635      False
# 3             67          58          0  District  2917  1910635      False
# 4             97          84          0  District  2917  1910635       True
#
#    read_pass  overall_pass
# 0      False         False
# 1       True         False
# 2       True         False
# ...

# %%
# Filter the data so that only 9th graders are in DataFrame
ninth_data_df = school_data_complete.loc[school_data_complete["grade"] == "9th"]
ninth_data_df.head()
# Out:
#     Student ID     student_name gender grade        school_name  \
# 0            0     Paul Bradley      M   9th  Huang High School
# 4            4       Bonnie Ray      F   9th  Huang High School
# 5            5    Bryan Miranda      M   9th  Huang High School
# 12          12  Brittney Walker      F   9th  Huang High School
# 13          13     William Long      M   9th  Huang High School
#
#     reading_score  math_score  School ID      type  size   budget  math_pass  \
# 0              66          79          0  District  2917  1910635       True
# 4              97          84          0  District  2917  1910635       True
# 5              94          94          0  District  2917  1910635       True
# 12             64          79          0  District  2917  1910635       True
# 13             71          79          0  District  2917  1910635       True
#
#     read_pass  overall_pass
# 0       False         False
# 4        True          True
# 5        True          True
# ...

# %%
ninth_group_df=ninth_data_df.groupby("school_name")
ninth_group_df.mean()
# Out:
#                          Student ID  reading_score  math_score  School ID  \
# school_name
# Bailey High School     20344.481481      81.303155   77.083676        7.0
# Cabrera High School    16969.634470      83.676136   83.094697        6.0
# Figueroa High School    4397.878505      81.198598   76.403037        1.0
# Ford High School       36170.595438      80.632653   77.361345       13.0
# Griffin High School    13031.305623      83.369193   82.044010        4.0
# Hernandez High School   9928.620839      80.866860   77.438495        3.0
# Holden High School     23068.314961      83.677165   83.787402        8.0
# Huang High School       1445.726303      81.290284   77.027251        0.0
# Johnson High School    32399.975714      81.260714   77.187857       12.0
# Pena High School       23766.127273      83.807273   83.625455        9.0
# Rodriguez High School  28017.408076      80.993127   76.859966       11.0
# ...

# %%
ninth_math=ninth_group_df["math_score"].mean()
ninth_math
# Out:
# school_name
# Bailey High School       77.083676
# Cabrera High School      83.094697
# Figueroa High School     76.403037
# Ford High School         77.361345
# Griffin High School      82.044010
# Hernandez High School    77.438495
# Holden High School       83.787402
# Huang High School        77.027251
# Johnson High School      77.187857
# Pena High School         83.625455
# Rodriguez High School    76.859966
# Shelton High School      83.420755
# Thomas High School       83.590022
# Wilson High School       83.085578
# Wright High School       83.264706
# Name: math_score, dtype: float64

# %%
# Filter the data so that only 10th graders are in DataFrame
tenth_data_df = school_data_complete.loc[school_data_complete["grade"] == "10th"]
tenth_data_df.head()
# Out:
#     Student ID      student_name gender grade        school_name  \
# 8            8      Michael Roth      M  10th  Huang High School
# 9            9    Matthew Greene      M  10th  Huang High School
# 10          10  Andrew Alexander      M  10th  Huang High School
# 11          11     Daniel Cooper      M  10th  Huang High School
# 14          14      Tammy Hebert      F  10th  Huang High School
#
#     reading_score  math_score  School ID      type  size   budget  math_pass  \
# 8              95          87          0  District  2917  1910635       True
# 9              96          84          0  District  2917  1910635       True
# 10             90          70          0  District  2917  1910635       True
# 11             78          77          0  District  2917  1910635       True
# 14             85          67          0  District  2917  1910635      False
#
#     read_pass  overall_pass
# 8        True          True
# 9        True          True
# ...

# %%
tenth_group_df=tenth_data_df.groupby("school_name")
tenth_math=tenth_group_df["math_score"].mean()
tenth_math
# Out:
# school_name
# Bailey High School       76.996772
# Cabrera High School      83.154506
# Figueroa High School     76.539974
# Ford High School         77.672316
# Griffin High School      84.229064
# Hernandez High School    77.337408
# Holden High School       83.429825
# Huang High School        75.908735
# Johnson High School      76.691117
# Pena High School         83.372000
# Rodriguez High School    76.612500
# Shelton High School      82.917411
# Thomas High School       83.087886
# Wilson High School       83.724422
# Wright High School       84.010288
# Name: math_score, dtype: float64

# %%
# Filter the data so that only 11th graders are in DataFrame
eleventh_data_df = school_data_complete.loc[school_data_complete["grade"] == "11th"]
eleventh_group_df=eleventh_data_df.groupby("school_name")
eleventh_math=eleventh_group_df["math_score"].mean()
eleventh_math
# Out:
# school_name
# Bailey High School       77.515588
# Cabrera High School      82.765560
# Figueroa High School     76.884344
# Ford High School         76.918058
# Griffin High School      83.842105
# Hernandez High School    77.136029
# Holden High School       85.000000
# Huang High School        76.446602
# Johnson High School      77.491653
# Pena High School         84.328125
# Rodriguez High School    76.395626
# Shelton High School      83.383495
# Thomas High School       83.498795
# Wilson High School       83.195326
# Wright High School       83.836782
# Name: math_score, dtype: float64

# %%
# Filter the data so that only 12th graders are in DataFrame
twelfth_data_df = school_data_complete.loc[school_data_complete["grade"] == "12th"]
twelfth_group_df=twelfth_data_df.groupby("school_name")
twelfth_math=twelfth_group_df["math_score"].mean()
twelfth_math
# Out:
# school_name
# Bailey High School       76.492218
# Cabrera High School      83.277487
# Figueroa High School     77.151369
# Ford High School         76.179963
# Griffin High School      83.356164
# Hernandez High School    77.186567
# Holden High School       82.855422
# Huang High School        77.225641
# Johnson High School      76.863248
# Pena High School         84.121547
# Rodriguez High School    77.690748
# Shelton High School      83.778976
# Thomas High School       83.497041
# Wilson High School       83.035794
# Wright High School       83.644986
# Name: math_score, dtype: float64

# %%
school_averages_math_df=pd.DataFrame({"9th":ninth_math,
                                      "10th":tenth_math, 
                                      "11th":eleventh_math, 
                                      "12th":twelfth_math})
school_averages_math_df
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
ninth_data_df = school_data_complete.loc[school_data_complete["grade"] == "9th"]
ninth_group_df=ninth_data_df.groupby("school_name")
ninth_read=ninth_group_df["reading_score"].mean()
ninth_read
# Out:
# school_name
# Bailey High School       81.303155
# Cabrera High School      83.676136
# Figueroa High School     81.198598
# Ford High School         80.632653
# Griffin High School      83.369193
# Hernandez High School    80.866860
# Holden High School       83.677165
# Huang High School        81.290284
# Johnson High School      81.260714
# Pena High School         83.807273
# Rodriguez High School    80.993127
# Shelton High School      84.122642
# Thomas High School       83.728850
# Wilson High School       83.939778
# Wright High School       83.833333
# Name: reading_score, dtype: float64

# %%
tenth_data_df = school_data_complete.loc[school_data_complete["grade"] == "10th"]
tenth_group_df=tenth_data_df.groupby("school_name")
tenth_read=tenth_group_df["reading_score"].mean()
tenth_read
# Out:
# school_name
# Bailey High School       80.907183
# Cabrera High School      84.253219
# Figueroa High School     81.408912
# Ford High School         81.262712
# Griffin High School      83.706897
# Hernandez High School    80.660147
# Holden High School       83.324561
# Huang High School        81.512386
# Johnson High School      80.773431
# Pena High School         83.612000
# Rodriguez High School    80.629808
# Shelton High School      83.441964
# Thomas High School       84.254157
# Wilson High School       84.021452
# Wright High School       83.812757
# Name: reading_score, dtype: float64

# %%
eleventh_data_df = school_data_complete.loc[school_data_complete["grade"] == "11th"]
eleventh_group_df=eleventh_data_df.groupby("school_name")
eleventh_read=eleventh_group_df["reading_score"].mean()
eleventh_read
# Out:
# school_name
# Bailey High School       80.945643
# Cabrera High School      83.788382
# Figueroa High School     80.640339
# Ford High School         80.403642
# Griffin High School      84.288089
# Hernandez High School    81.396140
# Holden High School       83.815534
# Huang High School        81.417476
# Johnson High School      80.616027
# Pena High School         84.335938
# Rodriguez High School    80.864811
# Shelton High School      84.373786
# Thomas High School       83.585542
# Wilson High School       83.764608
# Wright High School       84.156322
# Name: reading_score, dtype: float64

# %%
twelfth_data_df = school_data_complete.loc[school_data_complete["grade"] == "12th"]
twelfth_group_df=twelfth_data_df.groupby("school_name")
twelfth_read=twelfth_group_df["reading_score"].mean()
twelfth_read
# Out:
# school_name
# Bailey High School       80.912451
# Cabrera High School      84.287958
# Figueroa High School     81.384863
# Ford High School         80.662338
# Griffin High School      84.013699
# Hernandez High School    80.857143
# Holden High School       84.698795
# Huang High School        80.305983
# Johnson High School      81.227564
# Pena High School         84.591160
# Rodriguez High School    80.376426
# Shelton High School      82.781671
# Thomas High School       83.831361
# Wilson High School       84.317673
# Wright High School       84.073171
# Name: reading_score, dtype: float64

# %%
school_averages_read_df=pd.DataFrame({"9th":ninth_read,
                                      "10th":tenth_read, 
                                      "11th":eleventh_read, 
                                      "12th":twelfth_read})
school_averages_read_df
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
school_spending_df=school_reduce_df.copy()
school_spending_df
# Out:
#                      school_name      type  school_students  school_budget  \
# school_id
# 0              Huang High School  District             2917        1910635
# 1           Figueroa High School  District             2949        1884411
# 2            Shelton High School   Charter             1761        1056600
# 3          Hernandez High School  District             4635        3022020
# 4            Griffin High School   Charter             1468         917500
# 5             Wilson High School   Charter             2283        1319574
# 6            Cabrera High School   Charter             1858        1081356
# 7             Bailey High School  District             4976        3124928
# 8             Holden High School   Charter              427         248087
# 9               Pena High School   Charter              962         585858
# 10            Wright High School   Charter             1800        1049400
# ...

# %%
#Determine Max/MinSpending Per Student for bins 
print(school_spending_df["student_budget"].max())
print(school_spending_df["student_budget"].min())
# Out:
# 655.0
# 578.0

# %%
# Define the bins and groups
bins1=[0, 600, 650, 700]
groups1=["<$600", "$600-650", "$650+"]

# %%
# Place the data series into a new column inside of the DataFrame
school_spending_df["Spending Per Student"] = pd.cut(school_spending_df["student_budget"], bins1, labels=groups1)
school_spending_df
# Out:
#                      school_name      type  school_students  school_budget  \
# school_id
# 0              Huang High School  District             2917        1910635
# 1           Figueroa High School  District             2949        1884411
# 2            Shelton High School   Charter             1761        1056600
# 3          Hernandez High School  District             4635        3022020
# 4            Griffin High School   Charter             1468         917500
# 5             Wilson High School   Charter             2283        1319574
# 6            Cabrera High School   Charter             1858        1081356
# 7             Bailey High School  District             4976        3124928
# 8             Holden High School   Charter              427         248087
# 9               Pena High School   Charter              962         585858
# 10            Wright High School   Charter             1800        1049400
# ...

# %%
#Scores by Spending Per Student Dataframe
spending_group_df=school_spending_df.groupby("Spending Per Student")
spending_group_df.mean()
# Out:
#                       school_students  school_budget  student_budget  \
# Spending Per Student
# <$600                        1625.800       951003.4          584.80
# $600-650                     2936.125      1870219.5          633.75
# $650+                        3776.000      2466327.5          653.50
#
#                        math_avg   read_avg  math_passavg  read_passavg  \
# Spending Per Student
# <$600                 83.436210  83.892196     93.541501     96.459627
# $600-650              79.423466  82.044963     76.832677     86.725974
# $650+                 76.959583  81.058567     66.218444     81.089710
#
#                       overall_passavg
# Spending Per Student
# <$600                       90.273988
# $600-650                    67.594009
# $650+                       53.520696

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
school_size_df=school_reduce_df.copy()
school_size_df.head()
# Out:
#                      school_name      type  school_students  school_budget  \
# school_id
# 0              Huang High School  District             2917        1910635
# 1           Figueroa High School  District             2949        1884411
# 2            Shelton High School   Charter             1761        1056600
# 3          Hernandez High School  District             4635        3022020
# 4            Griffin High School   Charter             1468         917500
#
#            student_budget   math_avg   read_avg  math_passavg  read_passavg  \
# school_id
# 0                   655.0  76.629414  81.182722     65.683922     81.316421
# 1                   639.0  76.711767  81.158020     65.988471     80.739234
# 2                   600.0  83.359455  83.725724     93.867121     95.854628
# 3                   652.0  77.289752  80.934412     66.752967     80.862999
# 4                   625.0  83.351499  83.816757     93.392371     97.138965
#
#            overall_passavg
# ...

# %%
#Determine Max/MinSpending Per Student for bins 
print(school_spending_df["school_students"].max())
print(school_spending_df["school_students"].min())
# Out:
# 4976
# 427

# %%
# Define the bins and groups
bins2=[0, 1000, 2000, 5000]
groups2=["Small: <1000", "Medium: 1000-2000", "Large: 2000-5000"]

# %%
# Place the data series into a new column inside of the DataFrame
school_size_df["School Size"] = pd.cut(school_spending_df["school_students"], bins2, labels=groups2)
school_size_df.head()
# Out:
#                      school_name      type  school_students  school_budget  \
# school_id
# 0              Huang High School  District             2917        1910635
# 1           Figueroa High School  District             2949        1884411
# 2            Shelton High School   Charter             1761        1056600
# 3          Hernandez High School  District             4635        3022020
# 4            Griffin High School   Charter             1468         917500
#
#            student_budget   math_avg   read_avg  math_passavg  read_passavg  \
# school_id
# 0                   655.0  76.629414  81.182722     65.683922     81.316421
# 1                   639.0  76.711767  81.158020     65.988471     80.739234
# 2                   600.0  83.359455  83.725724     93.867121     95.854628
# 3                   652.0  77.289752  80.934412     66.752967     80.862999
# 4                   625.0  83.351499  83.816757     93.392371     97.138965
#
# ...

# %%
#Scores by School Size Dataframe
size_group_df=school_size_df.groupby("School Size")
size_group_df.mean()
# Out:
#                    school_students  school_budget  student_budget   math_avg  \
# School Size
# Small: <1000               694.500     416972.500         595.000  83.821598
# Medium: 1000-2000         1704.400    1029597.200         605.600  83.374684
# Large: 2000-5000          3657.375    2333437.125         635.375  77.746417
#
#                     read_avg  math_passavg  read_passavg  overall_passavg
# School Size
# Small: <1000       83.929843     93.550225     96.099437        89.883853
# Medium: 1000-2000  83.864438     93.599695     96.790680        90.621535
# Large: 2000-5000   81.344493     69.963361     82.766634        58.286003

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
school_type_df=school_reduce_df.copy()
school_type_df.head()
# Out:
#                      school_name      type  school_students  school_budget  \
# school_id
# 0              Huang High School  District             2917        1910635
# 1           Figueroa High School  District             2949        1884411
# 2            Shelton High School   Charter             1761        1056600
# 3          Hernandez High School  District             4635        3022020
# 4            Griffin High School   Charter             1468         917500
#
#            student_budget   math_avg   read_avg  math_passavg  read_passavg  \
# school_id
# 0                   655.0  76.629414  81.182722     65.683922     81.316421
# 1                   639.0  76.711767  81.158020     65.988471     80.739234
# 2                   600.0  83.359455  83.725724     93.867121     95.854628
# 3                   652.0  77.289752  80.934412     66.752967     80.862999
# 4                   625.0  83.351499  83.816757     93.392371     97.138965
#
#            overall_passavg
# ...

# %%
#Scores by School Type Dataframe
type_group_df=school_type_df.groupby("type")
type_group_df.mean()
# Out:
#           school_students  school_budget  student_budget   math_avg  \
# type
# Charter       1524.250000   9.126881e+05      599.500000  83.473852
# District      3853.714286   2.478275e+06      643.571429  76.956733
#
#            read_avg  math_passavg  read_passavg  overall_passavg
# type
# Charter   83.896421     93.620830     96.586489        90.432244
# District  80.966636     66.548453     80.799062        53.672208
